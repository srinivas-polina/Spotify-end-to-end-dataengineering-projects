# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#this is use for autentication

client_credentials_manager = SpotifyClientCredentials(client_id="3039b4ce119e44e0a3146dde2d71f48c", client_secret="2806d8d4ac654e4e95f5392748ac834d")

# %%
# creating spotify object to extarct the data from spotify
#this is use for athourisation, permission to access data from spotify API
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZF1DWTt3gMo0DLxA"

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZF1DWTt3gMo0DLxA']

# %%
playlist_link.split("/")[-1]
# Out:
# '37i9dQZF1DWTt3gMo0DLxA'

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
playlist_URI
# Out:
# '37i9dQZF1DWTt3gMo0DLxA'

# %%
## playlist_tracks is a function used to extract the tracks from uri
sp.playlist_tracks(playlist_URI)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTt3gMo0DLxA/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-06-16T12:40:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#     'available_markets': ['IN'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['IN'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#      'id': '1NhxK8JrKi6H4jjTEZgheV',
#      'images': [{'height': 640,
# ...

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
#in this api we have alubm,song and artist information
#all of the data stored inside the 'items' key

data['items']
# Out:
# {'added_at': '2024-07-23T09:08:34Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/c22452953754864a53bd7f433aef48a5a9f78189?cid=3039b4ce119e44e0a3146dde2d71f48c',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
#to access frist song in the 'items' list
data['items'][0]
# Out:
# {'added_at': '2024-06-16T12:40:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#   'available_markets': ['IN'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['IN'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#    'id': '1NhxK8JrKi6H4jjTEZgheV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c0625e1142f4e615cb9ca27e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c0625e1142f4e615cb9ca27e',
# ...

# %%
#to access secound song in the 'items' list, like this you can doo for all remaining
data['items'][1]
# Out:
# {'added_at': '2024-07-23T09:08:34Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/c22452953754864a53bd7f433aef48a5a9f78189?cid=3039b4ce119e44e0a3146dde2d71f48c',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
#to see how many songs information inside this list
len(data['items'])
# Out:
# 50

# %%
data['items'][0]
# Out:
# {'added_at': '2024-06-16T12:40:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#   'available_markets': ['IN'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['IN'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#    'id': '1NhxK8JrKi6H4jjTEZgheV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c0625e1142f4e615cb9ca27e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c0625e1142f4e615cb9ca27e',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '1NhxK8JrKi6H4jjTEZgheV'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-06-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/1NhxK8JrKi6H4jjTEZgheV'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/1NhxK8JrKi6H4jjTEZgheV'

# %%
#we want do to all tracks avalible in the list, for that we have write loop
track_list = []
for row in data['items']:
    track_id = row['track']['album']['id']
    track_name = row['track']['album']['name']
    total_tracks = row['track']['album']['total_tracks']
    track_release_date = row['track']['album']['release_date']
    track_url = row['track']['album']['external_urls']['spotify']
    track_elements = {'track_id':track_id, 'track_name':track_name,'total_tracks':total_tracks,'track_release_date':track_release_date,'track_url':track_url}
    print(track_elements)

    track_list.append(track_elements)
# Out:
# {'track_id': '1NhxK8JrKi6H4jjTEZgheV', 'track_name': 'Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)', 'total_tracks': 1, 'track_release_date': '2024-06-16', 'track_url': 'https://open.spotify.com/album/1NhxK8JrKi6H4jjTEZgheV'}
# {'track_id': '0eJwR4VRUiGRuU7wjG3QfD', 'track_name': 'Double ISMART', 'total_tracks': 1, 'track_release_date': '2024-07-01', 'track_url': 'https://open.spotify.com/album/0eJwR4VRUiGRuU7wjG3QfD'}
# {'track_id': '7gzl2DEz4LGnwM1qr5UIP5', 'track_name': 'Sooseki (From "Pushpa 2 The Rule") [TELUGU]', 'total_tracks': 1, 'track_release_date': '2024-05-29', 'track_url': 'https://open.spotify.com/album/7gzl2DEz4LGnwM1qr5UIP5'}
# {'track_id': '1OO05SXoc1JTyvGbxi75Pm', 'track_name': 'Fear Song (From "Devara Part 1") [Telugu]', 'total_tracks': 1, 'track_release_date': '2024-05-19', 'track_url': 'https://open.spotify.com/album/1OO05SXoc1JTyvGbxi75Pm'}
# ...

# %%
track_list
# Out:
# [{'track_id': '1NhxK8JrKi6H4jjTEZgheV',
#   'track_name': 'Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)',
#   'track_release_date': '2024-06-16',
#   'track_url': 'https://open.spotify.com/album/1NhxK8JrKi6H4jjTEZgheV'},
#  {'track_id': '0eJwR4VRUiGRuU7wjG3QfD',
#   'track_name': 'Double ISMART',
#   'track_release_date': '2024-07-01',
#   'track_url': 'https://open.spotify.com/album/0eJwR4VRUiGRuU7wjG3QfD'},
#  {'track_id': '7gzl2DEz4LGnwM1qr5UIP5',
#   'track_name': 'Sooseki (From "Pushpa 2 The Rule") [TELUGU]',
#   'track_release_date': '2024-05-29',
#   'track_url': 'https://open.spotify.com/album/7gzl2DEz4LGnwM1qr5UIP5'},
#  {'track_id': '1OO05SXoc1JTyvGbxi75Pm',
#   'track_name': 'Fear Song (From "Devara Part 1") [Telugu]',
#   'track_release_date': '2024-05-19',
#   'track_url': 'https://open.spotify.com/album/1OO05SXoc1JTyvGbxi75Pm'},
#  {'track_id': '1D5M0OXMaT1dV9MADSPgIg',
#   'track_name': 'Hungry Cheetah (From "They Call Him OG")',
# ...

# %%
## now extracting artist data
data['items']
# Out:
# [{'added_at': '2024-06-16T12:40:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#    'available_markets': ['IN'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['IN'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#     'id': '1NhxK8JrKi6H4jjTEZgheV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c0625e1142f4e615cb9ca27e',
#       'width': 640},
#      {'height': 300,
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'},
#   'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR',
#   'id': '2FKWNmZWDBZR4dE5KX4plR',
#   'name': 'Diljit Dosanjh',
#   'type': 'artist',
#   'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5iFKS1bnBNFWBAmd7mi0vf'},
#   'href': 'https://api.spotify.com/v1/artists/5iFKS1bnBNFWBAmd7mi0vf',
#   'id': '5iFKS1bnBNFWBAmd7mi0vf',
#   'name': 'Deepak Blue',
#   'type': 'artist',
#   'uri': 'spotify:artist:5iFKS1bnBNFWBAmd7mi0vf'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'},
#   'href': 'https://api.spotify.com/v1/artists/5FVBduYaeVBb6JIghza7v6',
#   'id': '5FVBduYaeVBb6JIghza7v6',
#   'name': 'Santhosh Narayanan',
#   'type': 'artist',
#   'uri': 'spotify:artist:5FVBduYaeVBb6JIghza7v6'}]

# %%
#inside artist dict there is multiple artist lists
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Diljit Dosanjh'

# %%
#we need to access multiple lists in one dict, for that we need to write loop
for row in data['items']:
    for key,value in row.items():
        if key =="track":
          print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'}, 'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR', 'id': '2FKWNmZWDBZR4dE5KX4plR', 'name': 'Diljit Dosanjh', 'type': 'artist', 'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5iFKS1bnBNFWBAmd7mi0vf'}, 'href': 'https://api.spotify.com/v1/artists/5iFKS1bnBNFWBAmd7mi0vf', 'id': '5iFKS1bnBNFWBAmd7mi0vf', 'name': 'Deepak Blue', 'type': 'artist', 'uri': 'spotify:artist:5iFKS1bnBNFWBAmd7mi0vf'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'}, 'href': 'https://api.spotify.com/v1/artists/5FVBduYaeVBb6JIghza7v6', 'id': '5FVBduYaeVBb6JIghza7v6', 'name': 'Santhosh Narayanan', 'type': 'artist', 'uri': 'spotify:artist:5FVBduYaeVBb6JIghza7v6'}]
# ...

# %%
#to get the artists information
for row in data['items']:
    for key,value in row.items():
        if key =="track":
          for artist in value['artists']:
              print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'}, 'href': 'https://api.spotify.com/v1/artists/2FKWNmZWDBZR4dE5KX4plR', 'id': '2FKWNmZWDBZR4dE5KX4plR', 'name': 'Diljit Dosanjh', 'type': 'artist', 'uri': 'spotify:artist:2FKWNmZWDBZR4dE5KX4plR'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5iFKS1bnBNFWBAmd7mi0vf'}, 'href': 'https://api.spotify.com/v1/artists/5iFKS1bnBNFWBAmd7mi0vf', 'id': '5iFKS1bnBNFWBAmd7mi0vf', 'name': 'Deepak Blue', 'type': 'artist', 'uri': 'spotify:artist:5iFKS1bnBNFWBAmd7mi0vf'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'}, 'href': 'https://api.spotify.com/v1/artists/5FVBduYaeVBb6JIghza7v6', 'id': '5FVBduYaeVBb6JIghza7v6', 'name': 'Santhosh Narayanan', 'type': 'artist', 'uri': 'spotify:artist:5FVBduYaeVBb6JIghza7v6'}
# ...

# %%
#to get only the ids of artists
for row in data['items']:
    for key,value in row.items():
        if key =="track":
          for artist in value['artists']:
              print(artist['id'])
# Out:
# 2FKWNmZWDBZR4dE5KX4plR
# 5iFKS1bnBNFWBAmd7mi0vf
# 5FVBduYaeVBb6JIghza7v6
# 3AMxH9QIPZbK8ND8C9j4Ss
# 6LWyVEIBnx7MoRBhQxu9om
# 01dP5AXWzqsUZj4VIcUSDM
# 1BuW9BEbBIhDu6F13TVxpu
# 0oOet2f43PA68X5RxKobEy
# 5sSzCxHtgL82pYDvx2QyEU
# 3gZ3IpjebAehFzIYhFIJDK
# 4zCH9qm4R2DADamUHMCa6O
# 4GISoVSxo2LkF5EyorXs9W
# 2FgHPfRprDaylrSRVf1UlN
# 5ds7YHzRIeaGrAKGPR62fA
# 1cXMzsmYVsprIfgnqOmgRg
# 74S8YRi4XQ5yf9ToSzuY80
# 5pBJLl0z3HoPLzPI95P6PN
# 4zCH9qm4R2DADamUHMCa6O
# 2n2CcYTvgrHcpKGDHtelgz
# 6tV6eU1gwsruSzN4PyDJWe
# 4bOqW6xGi7n9315ErmJ2Um
# 4YRxDV8wJFPHPTeXepOstw
# 2yvOLf1gt6m9qPgzzqpxQx
# 2FgHPfRprDaylrSRVf1UlN
# 06V3WlbxMpgl639AJoFH7C
# 01dP5AXWzqsUZj4VIcUSDM
# 3fHBN4cBo24hLf8jnCUTYK
# 4qVlHvud9UIJTJZsRL27kk
# 4kq8z3vydHjPDggxb16ErB
# 5iFKS1bnBNFWBAmd7mi0vf
# 5sSzCxHtgL82pYDvx2QyEU
# 3gZ3IpjebAehFzIYhFIJDK
# 5FVBduYaeVBb6JIghza7v6
# 6ivte6aFersdzMprXpVDiO
# 06vOoTzj6cIac9FMbNXz9h
# 5UJ2sHO2ELrgW6aXeRLTQQ
# 0L5f9aJIaxQXTipZ7uQYiC
# 7M1gYudbPTr899NHeTOEHY
# 3MVZmcDNyoI81ZmAu0YiF7
# 4wxBWsFkyA2K1BMBFj91qt
# ...

# %%
#to get only the urls of artists
for row in data['items']:
    for key,value in row.items():
        if key =="track":
          for artist in value['artists']:
              print(artist['external_urls']['spotify'])
# Out:
# https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR
# https://open.spotify.com/artist/5iFKS1bnBNFWBAmd7mi0vf
# https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6
# https://open.spotify.com/artist/3AMxH9QIPZbK8ND8C9j4Ss
# https://open.spotify.com/artist/6LWyVEIBnx7MoRBhQxu9om
# https://open.spotify.com/artist/01dP5AXWzqsUZj4VIcUSDM
# https://open.spotify.com/artist/1BuW9BEbBIhDu6F13TVxpu
# https://open.spotify.com/artist/0oOet2f43PA68X5RxKobEy
# https://open.spotify.com/artist/5sSzCxHtgL82pYDvx2QyEU
# https://open.spotify.com/artist/3gZ3IpjebAehFzIYhFIJDK
# https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O
# https://open.spotify.com/artist/4GISoVSxo2LkF5EyorXs9W
# https://open.spotify.com/artist/2FgHPfRprDaylrSRVf1UlN
# https://open.spotify.com/artist/5ds7YHzRIeaGrAKGPR62fA
# https://open.spotify.com/artist/1cXMzsmYVsprIfgnqOmgRg
# https://open.spotify.com/artist/74S8YRi4XQ5yf9ToSzuY80
# https://open.spotify.com/artist/5pBJLl0z3HoPLzPI95P6PN
# ...

# %%
#creating a dictionary directly on top of this code
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key =="track":
          for artist in value['artists']:
              artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'artist_uri':artist['external_urls']['spotify']}
              artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2FKWNmZWDBZR4dE5KX4plR',
#   'artist_name': 'Diljit Dosanjh',
#   'artist_uri': 'https://open.spotify.com/artist/2FKWNmZWDBZR4dE5KX4plR'},
#  {'artist_id': '5iFKS1bnBNFWBAmd7mi0vf',
#   'artist_name': 'Deepak Blue',
#   'artist_uri': 'https://open.spotify.com/artist/5iFKS1bnBNFWBAmd7mi0vf'},
#  {'artist_id': '5FVBduYaeVBb6JIghza7v6',
#   'artist_name': 'Santhosh Narayanan',
#   'artist_uri': 'https://open.spotify.com/artist/5FVBduYaeVBb6JIghza7v6'},
#  {'artist_id': '3AMxH9QIPZbK8ND8C9j4Ss',
#   'artist_name': 'Mani Sharma',
#   'artist_uri': 'https://open.spotify.com/artist/3AMxH9QIPZbK8ND8C9j4Ss'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
#   'artist_uri': 'https://open.spotify.com/artist/6LWyVEIBnx7MoRBhQxu9om'},
#  {'artist_id': '01dP5AXWzqsUZj4VIcUSDM',
#   'artist_name': 'Sahithi Chaganti',
#   'artist_uri': 'https://open.spotify.com/artist/01dP5AXWzqsUZj4VIcUSDM'},
#  {'artist_id': '1BuW9BEbBIhDu6F13TVxpu',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#  'available_markets': ['IN'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['IN'],
#   'type': 'album',
#   'album_type': 'single',
#   'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#   'id': '1NhxK8JrKi6H4jjTEZgheV',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c0625e1142f4e615cb9ca27e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c0625e1142f4e615cb9ca27e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c0625e1142f4e615cb9ca27e',
#     'width': 64}],
#   'name': 'Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)',
#   'release_date': '2024-06-16',
#   'release_date_precision': 'day',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-06-16T12:40:05Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b1af934b9048122586a7f8b40aa2bccdb5d6397d?cid=3039b4ce119e44e0a3146dde2d71f48c',
#   'available_markets': ['IN'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['IN'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/1NhxK8JrKi6H4jjTEZgheV',
#    'id': '1NhxK8JrKi6H4jjTEZgheV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c0625e1142f4e615cb9ca27e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c0625e1142f4e615cb9ca27e',
# ...

# %%
#song information 

song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_popularity = row['track']['popularity']
    song_url = row['track']['external_urls']['spotify']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id']
    song_element = { 'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'song_popularity ':song_popularity ,'song_url':song_url,'song_added':song_added,'album_id':album_id,'artist_id ':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '5kNydYWkUyXh4zVoy8QDmC',
#   'song_name': 'Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)',
#   'song_duration': 163354,
#   'song_popularity ': 64,
#   'song_url': 'https://open.spotify.com/track/5kNydYWkUyXh4zVoy8QDmC',
#   'song_added': '2024-06-16T12:40:05Z',
#   'album_id': '1NhxK8JrKi6H4jjTEZgheV',
#   'artist_id ': '2FKWNmZWDBZR4dE5KX4plR'},
#  {'song_id': '7vLR2TSzHEVUNlKm5dcYpo',
#   'song_name': 'SteppaMaar',
#   'song_duration': 232602,
#   'song_popularity ': 56,
#   'song_url': 'https://open.spotify.com/track/7vLR2TSzHEVUNlKm5dcYpo',
#   'song_added': '2024-07-23T09:08:34Z',
#   'album_id': '0eJwR4VRUiGRuU7wjG3QfD',
#   'artist_id ': '3AMxH9QIPZbK8ND8C9j4Ss'},
#  {'song_id': '2gKNWPBrI2IRBl2RRUtoEb',
#   'song_name': 'Sooseki (From "Pushpa 2 The Rule") [TELUGU]',
#   'song_duration': 260177,
#   'song_popularity ': 70,
#   'song_url': 'https://open.spotify.com/track/2gKNWPBrI2IRBl2RRUtoEb',
#   'song_added': '2024-06-05T09:12:34Z',
# ...

# %%
#creating album dataframe
album_df = pd.DataFrame.from_dict(track_list)

# %%
album_df
# Out:
#                   track_id                                         track_name  \
# 0   1NhxK8JrKi6H4jjTEZgheV    Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1   0eJwR4VRUiGRuU7wjG3QfD                                      Double ISMART
# 2   7gzl2DEz4LGnwM1qr5UIP5        Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3   1OO05SXoc1JTyvGbxi75Pm          Fear Song (From "Devara Part 1") [Telugu]
# 4   1D5M0OXMaT1dV9MADSPgIg           Hungry Cheetah (From "They Call Him OG")
# 5   3UtsdAsNLgSakD8UYYXf4o            Gumma (From "Ambajipeta Marriage Band")
# 6   6kl5gAF0jqGb9iKdLVGBHr                                             Murari
# 7   0bjug1LVXNf7WiAqNUHjLr                     Souraa (From "Bharateeyudu 2")
# 8   5Bf9d0EGx9J7m0xHA9Q3Tr                                      Om Bheem Bush
# 9   43yBwxxfwX5mpyHxFLkqdn                                      Guntur Kaaram
# 10  18hhin8Y0j4EeOn3G2PYXX  Pushpa Pushpa (From "Pushpa 2 The Rule") [TELUGU]
# ...

# %%
#creating artist information as dataframe
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id         artist_name  \
# 0    2FKWNmZWDBZR4dE5KX4plR      Diljit Dosanjh
# 1    5iFKS1bnBNFWBAmd7mi0vf         Deepak Blue
# 2    5FVBduYaeVBb6JIghza7v6  Santhosh Narayanan
# 3    3AMxH9QIPZbK8ND8C9j4Ss         Mani Sharma
# 4    6LWyVEIBnx7MoRBhQxu9om     Anurag Kulkarni
# ..                      ...                 ...
# 112  0LSPREIgGMZXCuKVel7LVD             Karthik
# 113  0WpkyIAATl5W540KCSEUwX           Sumangaly
# 114  5VVN3xZw1i2qihfITZlvCZ       G. V. Prakash
# 115  4K42hgH9ltvSq74hcOC85P           Siddharth
# 116  4joteb3wCfZYGKjvF0XvLx        Prashanthini
#
#                                             artist_uri
# 0    https://open.spotify.com/artist/2FKWNmZWDBZR4d...
# 1    https://open.spotify.com/artist/5iFKS1bnBNFWBA...
# 2    https://open.spotify.com/artist/5FVBduYaeVBb6J...
# 3    https://open.spotify.com/artist/3AMxH9QIPZbK8N...
# 4    https://open.spotify.com/artist/6LWyVEIBnx7MoR...
# ...

# %%
#creating song information as dataframe
song_df = pd.DataFrame.from_dict(song_list)
song_df
# Out:
#                    song_id                                          song_name  \
# 0   5kNydYWkUyXh4zVoy8QDmC    Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1   7vLR2TSzHEVUNlKm5dcYpo                                         SteppaMaar
# 2   2gKNWPBrI2IRBl2RRUtoEb        Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3   6b2WJDzGt5X8dYfpkWtvXW          Fear Song (From "Devara Part 1") [Telugu]
# 4   538V6gFAnhcLZrg6I8lIMI           Hungry Cheetah (From "They Call Him OG")
# 5   30CBQmKZ0fugbhs7ExGT1e            Gumma (From "Ambajipeta Marriage Band")
# 6   2SyVdOenmbDSjUGoFprS2x                              Alanati Ramachandrudu
# 7   6EQVXaIi22Ilmkt1Coi9gZ                     Souraa (From "Bharateeyudu 2")
# 8   0kNe3kmRFq7eKVlL15h7nb                                         Anuvanuvuu
# 9   0hY9eA74QrMCJuWEx7fo9y                                Kurchi Madathapetti
# 10  5bnxMZqd9Kpn9ByHj3Dc9C  Pushpa Pushpa (From "Pushpa 2 The Rule") [TELUGU]
# ...

# %%
print(song_df.columns)
# Out:
# Index(['song_id', 'song_name', 'song_duration', 'song_popularity ', 'song_url',
#        'song_added', 'album_id', 'artist_id '],
#       dtype='object')

# %%
print(album_df.columns)
# Out:
# Index(['track_id', 'track_name', 'track_release_date', 'track_url'], dtype='object')

# %%
print(artist_df.columns)
# Out:
# Index(['artist_id', 'artist_name', 'artist_uri'], dtype='object')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            50 non-null     object
#  1   track_name          50 non-null     object
#  2   track_release_date  50 non-null     object
#  3   track_url           50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
album_df.head()
# Out:
#                     track_id  \
# 0  (1NhxK8JrKi6H4jjTEZgheV,)
# 1  (0eJwR4VRUiGRuU7wjG3QfD,)
# 2  (7gzl2DEz4LGnwM1qr5UIP5,)
# 3  (1OO05SXoc1JTyvGbxi75Pm,)
# 4  (1D5M0OXMaT1dV9MADSPgIg,)
#
#                                           track_name track_release_date  \
# 0  (Bhairava Anthem (From "Kalki 2898 Ad") (Telug...      (2024-06-16,)
# 1                                   (Double ISMART,)      (2024-07-01,)
# 2     (Sooseki (From "Pushpa 2 The Rule") [TELUGU],)      (2024-05-29,)
# 3       (Fear Song (From "Devara Part 1") [Telugu],)      (2024-05-19,)
# 4        (Hungry Cheetah (From "They Call Him OG"),)      (2023-09-03,)
#
#                                            track_url
# 0  https://open.spotify.com/album/1NhxK8JrKi6H4jj...
# 1  https://open.spotify.com/album/0eJwR4VRUiGRuU7...
# 2  https://open.spotify.com/album/7gzl2DEz4LGnwM1...
# 3  https://open.spotify.com/album/1OO05SXoc1JTyvG...
# 4  https://open.spotify.com/album/1D5M0OXMaT1dV9M...

# %%
song_df.head()
# Out:
#                   song_id                                        song_name  \
# 0  5kNydYWkUyXh4zVoy8QDmC  Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1  7vLR2TSzHEVUNlKm5dcYpo                                       SteppaMaar
# 2  2gKNWPBrI2IRBl2RRUtoEb      Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3  6b2WJDzGt5X8dYfpkWtvXW        Fear Song (From "Devara Part 1") [Telugu]
# 4  538V6gFAnhcLZrg6I8lIMI         Hungry Cheetah (From "They Call Him OG")
#
#    song_duration  song_popularity   \
# 0         163354                64
# 1         232602                56
# 2         260177                70
# 3         195064                71
# 4         119052                63
#
#                                             song_url            song_added  \
# 0  https://open.spotify.com/track/5kNydYWkUyXh4zV...  2024-06-16T12:40:05Z
# 1  https://open.spotify.com/track/7vLR2TSzHEVUNlK...  2024-07-23T09:08:34Z
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           50 non-null     object
#  1   song_name         50 non-null     object
#  2   song_duration     50 non-null     int64
#  3   song_popularity   50 non-null     int64
#  4   song_url          50 non-null     object
#  5   song_added        50 non-null     object
#  6   album_id          50 non-null     object
#  7   artist_id         50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
artist_df.head()
# Out:
#                 artist_id         artist_name  \
# 0  2FKWNmZWDBZR4dE5KX4plR      Diljit Dosanjh
# 1  5iFKS1bnBNFWBAmd7mi0vf         Deepak Blue
# 2  5FVBduYaeVBb6JIghza7v6  Santhosh Narayanan
# 3  3AMxH9QIPZbK8ND8C9j4Ss         Mani Sharma
# 4  6LWyVEIBnx7MoRBhQxu9om     Anurag Kulkarni
#
#                                           artist_uri
# 0  https://open.spotify.com/artist/2FKWNmZWDBZR4d...
# 1  https://open.spotify.com/artist/5iFKS1bnBNFWBA...
# 2  https://open.spotify.com/artist/5FVBduYaeVBb6J...
# 3  https://open.spotify.com/artist/3AMxH9QIPZbK8N...
# 4  https://open.spotify.com/artist/6LWyVEIBnx7MoR...

# %%
#to droping the duplicates
album_df  = album_df.drop_duplicates(subset = ['track_id'])

# %%
artist_df  = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
##we dont need to drop the duplictaes from songs df because they are prety much unique

# %%
album_df
# Out:
#                   track_id                                         track_name  \
# 0   1NhxK8JrKi6H4jjTEZgheV    Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1   0eJwR4VRUiGRuU7wjG3QfD                                      Double ISMART
# 2   7gzl2DEz4LGnwM1qr5UIP5        Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3   1OO05SXoc1JTyvGbxi75Pm          Fear Song (From "Devara Part 1") [Telugu]
# 4   1D5M0OXMaT1dV9MADSPgIg           Hungry Cheetah (From "They Call Him OG")
# 5   3UtsdAsNLgSakD8UYYXf4o            Gumma (From "Ambajipeta Marriage Band")
# 6   6kl5gAF0jqGb9iKdLVGBHr                                             Murari
# 7   0bjug1LVXNf7WiAqNUHjLr                     Souraa (From "Bharateeyudu 2")
# 8   5Bf9d0EGx9J7m0xHA9Q3Tr                                      Om Bheem Bush
# 9   43yBwxxfwX5mpyHxFLkqdn                                      Guntur Kaaram
# 10  18hhin8Y0j4EeOn3G2PYXX  Pushpa Pushpa (From "Pushpa 2 The Rule") [TELUGU]
# ...

# %%
#changing the formate of date column and we have two errors in the table replacing with NaT
album_df['track_release_date'] = pd.to_datetime(album_df['track_release_date'], errors='coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            50 non-null     object
#  1   track_name          50 non-null     object
#  2   total_tracks        50 non-null     int64
#  3   track_release_date  48 non-null     datetime64[ns]
#  4   track_url           50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
album_df
# Out:
#                   track_id                                         track_name  \
# 0   1NhxK8JrKi6H4jjTEZgheV    Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1   0eJwR4VRUiGRuU7wjG3QfD                                      Double ISMART
# 2   7gzl2DEz4LGnwM1qr5UIP5        Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3   1OO05SXoc1JTyvGbxi75Pm          Fear Song (From "Devara Part 1") [Telugu]
# 4   1D5M0OXMaT1dV9MADSPgIg           Hungry Cheetah (From "They Call Him OG")
# 5   3UtsdAsNLgSakD8UYYXf4o            Gumma (From "Ambajipeta Marriage Band")
# 6   6kl5gAF0jqGb9iKdLVGBHr                                             Murari
# 7   0bjug1LVXNf7WiAqNUHjLr                     Souraa (From "Bharateeyudu 2")
# 8   5Bf9d0EGx9J7m0xHA9Q3Tr                                      Om Bheem Bush
# 9   43yBwxxfwX5mpyHxFLkqdn                                      Guntur Kaaram
# 10  18hhin8Y0j4EeOn3G2PYXX  Pushpa Pushpa (From "Pushpa 2 The Rule") [TELUGU]
# ...

# %%
#if we want to delete the df
del album_df

# %%
album_df
# Out:
#                   track_id                                         track_name  \
# 0   1NhxK8JrKi6H4jjTEZgheV    Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1   0eJwR4VRUiGRuU7wjG3QfD                                      Double ISMART
# 2   7gzl2DEz4LGnwM1qr5UIP5        Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3   1OO05SXoc1JTyvGbxi75Pm          Fear Song (From "Devara Part 1") [Telugu]
# 4   1D5M0OXMaT1dV9MADSPgIg           Hungry Cheetah (From "They Call Him OG")
# 5   3UtsdAsNLgSakD8UYYXf4o            Gumma (From "Ambajipeta Marriage Band")
# 6   6kl5gAF0jqGb9iKdLVGBHr                                             Murari
# 7   0bjug1LVXNf7WiAqNUHjLr                     Souraa (From "Bharateeyudu 2")
# 8   5Bf9d0EGx9J7m0xHA9Q3Tr                                      Om Bheem Bush
# 9   43yBwxxfwX5mpyHxFLkqdn                                      Guntur Kaaram
# 10  18hhin8Y0j4EeOn3G2PYXX  Pushpa Pushpa (From "Pushpa 2 The Rule") [TELUGU]
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           50 non-null     object
#  1   song_name         50 non-null     object
#  2   song_duration     50 non-null     int64
#  3   song_popularity   50 non-null     int64
#  4   song_url          50 non-null     object
#  5   song_added        50 non-null     datetime64[ns, UTC]
#  6   album_id          50 non-null     object
#  7   artist_id         50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76 entries, 0 to 109
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    76 non-null     object
#  1   artist_name  76 non-null     object
#  2   artist_uri   76 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
song_df.head()
# Out:
#                   song_id                                        song_name  \
# 0  5kNydYWkUyXh4zVoy8QDmC  Bhairava Anthem (From "Kalki 2898 Ad") (Telugu)
# 1  7vLR2TSzHEVUNlKm5dcYpo                                       SteppaMaar
# 2  2gKNWPBrI2IRBl2RRUtoEb      Sooseki (From "Pushpa 2 The Rule") [TELUGU]
# 3  6b2WJDzGt5X8dYfpkWtvXW        Fear Song (From "Devara Part 1") [Telugu]
# 4  538V6gFAnhcLZrg6I8lIMI         Hungry Cheetah (From "They Call Him OG")
#
#    song_duration  song_popularity   \
# 0         163354                64
# 1         232602                56
# 2         260177                70
# 3         195064                71
# 4         119052                63
#
#                                             song_url  \
# 0  https://open.spotify.com/track/5kNydYWkUyXh4zV...
# 1  https://open.spotify.com/track/7vLR2TSzHEVUNlK...
# 2  https://open.spotify.com/track/2gKNWPBrI2IRBl2...
# 3  https://open.spotify.com/track/6b2WJDzGt5X8dYf...
# ...
